# %%
# %cd ../../
# Out:
# /home/PJWSTK/s14028/Engine

# %%
import keras

from common import *
from testing import test_model
from testing import best_cop_diff
from testing import mse
from testing import mae

from CNN.CNN_v0 import CNN_v0
# Out:
# Using TensorFlow backend.

# %%
train, test = data_sets()
image_tensors = train[0], test[0]
person_coo_tensors = train[1], test[1]
count_matrix = train[2], test[2]

image_train, image_test = image_tensors
person_coo_train, person_coo_test = person_coo_tensors
count_train, count_test = count_matrix
count_train = count_train.astype(np.uint16)
count_test = count_test.astype(np.uint16)

# %%
cnn = CNN_v0((480, 640, 3), split_into_parts=40)

images = cnn._prepare_images(image_test)
anwsers = cnn._prepare_anwsers(person_coo_test)

# %%
cop = np.linspace(0, 1, 11)[1:-1]

# %%
prefix = "CNN/CNN_v0/weights/"

# %%
model_names = ["cnn_v0_40_1e_1_100",
               "cnn_v0_40_1e_1_200",
               "cnn_v0_40_1e_1_300",
               "cnn_v0_40_1e_4_30",
               "cnn_v0_40_1e_2_150_2",
               "cnn_v0_40_1e_2_250_2",
               "cnn_v0_40_1e_7_10_2",
               "cnn_v0_40_1e_7_40_2",
               "cnn_v0_40_1e_8_30_2"]

model_names = [prefix + name for name in model_names]

# %%
models = [CNN_v0((480, 640, 3), split_into_parts=40) for i in range(len(model_names))]

# %%
results = {}

for model_name, model in zip(model_names, models):
  model.def_model()
  model.model.fit(images[:1], anwsers[:1])
  
  model.model = keras.utils.multi_gpu_model(model.model, gpus=3, cpu_merge=False)
  model.model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
  
  model.model.load_weights(model_name)
  
  results[model_name] = test_model(model=model, images=image_test, counts=count_test, cut_of_points=cop)
# Out:
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.6931 - acc: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 638ms/step - loss: 0.6931 - acc: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 710ms/step - loss: 0.6931 - acc: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.6931 - acc: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 944ms/step - loss: 0.6931 - acc: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.6931 - acc: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.6931 - acc: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.6931 - acc: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.6931 - acc: 1.0000

# %%
for name, result in results.items():
  diff = best_cop_diff(result, count_test)
  
  print(f"Model {name} behaved:")
  
  print(f"For cut-of-point {diff[0]} had accuracy {diff[1]}:")
  print(diff[2])
  
  print(f"With MSE {mse(diff[2])}")
  print(f"With MAE {mae(diff[2])}", end="\n\n")
# Out:
# Model CNN/CNN_v0/weights/cnn_v0_40_1e_1_100 behaved:
# For cut-of-point 0.2 had accuracy 83.07451466254764:
# [ -5  -9  -9   7   0   0   4   0   6   2  -2   5   1  -2  -1   7  -2  -1
#   10  -1  -4   3   5  -1  -5  -6  -2  -6  -4   3  -1  -7  -4  -3   4   0
#   -9 -10 -18 -11  -9 -15 -16 -15  -9 -14 -14 -11 -16 -11 -12 -15 -16 -16
#  -19 -14 -12 -15 -15 -12  -4 -13  -9  -9 -19 -11 -15 -13  -8  -6 -14 -15
#  -12  -9 -17 -14 -10 -13  -5 -11 -19 -10  -6 -14 -10  -8 -14 -11  -4  -4
#   -7 -12 -13 -15 -11  -8 -15 -14  -9 -11 -17  -9 -14 -20 -13  -8 -11  -7
#  -12  -7  -6  -6  -4  -5  -6  -6 -10 -12 -10 -16 -13 -15 -15 -14 -20 -11
#   -7  -6 -11 -14  -5 -15  -8  -8  -3  -7   0 -11  -2 -17 -20 -21 -20 -20
#  -10  -9 -12 -16 -11 -18 -22 -22 -22 -12 -22 -17 -29 -14 -17 -10 -10 -15
#  -15 -12  -8  -9  -5 -12 -16 -16 -11  -9 -14 -18 -16  -9 -16 -15 -19 -17
#  -23 -21 -20 -26 -12  -5 -12 -11 -10  -8 -11 -12  -5 -17 -11  -2 -11 -12
#  -12  -6 -13  -1 -10 -13  -8  -7 -14 -12 -14  -7]
# With MSE 167.34666666666666
# With MAE 11.733333333333333
#
# Model CNN/CNN_v0/weights/cnn_v0_40_1e_2_150_2 behaved:
# For cut-of-point 0.1 had accuracy 69.09388288462102:
# [ 11  16  12  15  24  18   4  -5   0   0  -1   3  -1   5   2   9  17   5
#   13  14   6   1   2   0   3  -6   2  10   2  -1   5   0  -1   5  15  18
#   25   5  27  19  12  13  21   6  15  14  17  17  14  17   9   6   3   8
#    3   5   9  10  19  15  32  12   9  10   1   6  -6  -7   4   7   4   3
#    7  13  11   9   5   7   3   2  -6   8   5   4   3  -4  -4  -4   8  10
#   15  15  13  -1   8 -10   8  -5   2   7  15  10  29  20  22  11  14  19
#   14  16  12  21  23  16  22  33  23  20   3  16   0  16   7  12   2  10
#    6   9  10  15  29   8   7  14  35  18  12  12  13  19  -6   5   4  -3
#   26   9   6  14  15   3  10   7  10   8   1   2   4   4   9   5   6   5
#   10   7   5  10  15   2   2   9   1  13   1  10   9   9  10   6   8   6
#   12  -3   5   2  -3  13   3   8   7   1  -6   6   9   4   1   6   8   8
#    4   9   7  16   8  17   9  10  11   9  10   5   5  22  12   6   1  12
#   21  18  11   6  28  13  19  22  18  15  10   9  13   2  11  26  23  11
#    6  10  15   9   0  16   8   6  15  14   1  29   6   6  11  12   3   0
#    7  11   8  14  10   0   5  17   0  12   6  -2  14  28  13  14   6   9
#    6   6   3  -5   8  12  15   3  11  12  -1   9  11   6  10   9   6   2
#    3   2  10  16  -2  -4  -1  17   5   3   3   4]
# With MSE 138.15666666666667
# With MAE 9.563333333333333
#
# Model CNN/CNN_v0/weights/cnn_v0_40_1e_2_250_2 behaved:
# For cut-of-point 0.2 had accuracy 83.26226111454567:
# [-11   2  -7  -8  -4   3  -9 -10  -9  -6  -5   0  -6  -4  -5   2   4  -3
#   -2  -1  -3  -8  -6  -8   1  -9  -1  -1   0  -3   3  -7  -5  -3   1   2
#    9  -3  12   0  -3  -3   5  -4  -2   0   9   9   1  -1  -2  -1  -7  -3
#   -5  -1  -7  -2   9  -4   6  -2  -7  -3  -6  -5 -17 -17  -7  -4 -11  -5
#   -2  -3  -1   0   0  -3  -7  -4 -14   0  -4  -5  -6 -15  -8 -12   1  -3
#    4  -6   0 -18  -9 -19  -7 -23  -6  -7   2  -8   7   0   1   1   0  -2
#  -12  -4  -4   0   3  -2  -2   3   8  -4  -9   4 -13  -3  -1  -6 -10   1
#   -5  -4   3  -1   3   1  -6  -6   6  -7   1  -2  -2  -3 -19 -13 -11 -20
#    2  -5  -9   0  -7  -8   0  -7  -3  -6  -6  -8  -6  -5  -6  -5  -6  -6
#   -2  -6  -7  -2   2  -8  -5   0  -5   3  -6  -2   1  -2  -7  -1  -4  -7
#    0 -10  -6  -7  -6   6  -9  -8   2  -4 -13   0  -9  -7  -5  -3   2  -3
#   -4  -6   0   8  -1   3  -3  -1  -2   1   3  -7  -4   0  -4  -2 -11  -3
#   -1   1   2  -4  10  -9  -7  -1   3   3   1  -1   1 -13  -6   0  -2  -6
#   -5   0  -4  -2  -6  -1  -9  -9  -8  -5 -14   0 -18 -15  -9  -2  -7  -9
#   -4  -5  -5   3   1  -5 -10   1  -7  -2  -8  -9  -4   3  -6  -2  -6  -9
#   -4 -15 -17 -17  -4  -1   3  -8  -1   3 -11  -3  -3  -8  -4  -2  -6  -9
#   -5  -4   3   2 -11 -11  -4   5  -7  -1  -9  -9]
# With MSE 44.74666666666667
# With MAE 5.22
#
# Model CNN/CNN_v0/weights/cnn_v0_40_1e_7_10_2 behaved:
# For cut-of-point 0.2 had accuracy 85.70510340633322:
# [  1  12   0   3  -1  12  -5  -8  -5  -2  -4   0  -6   1  -4   1  10  -1
#    1   2   0  -3  -5  -3  -1 -11   0   5   1  -3   3  -5  -2  -2   3   8
#   15   4  17   8   0   1  10  -2   3   4  13  13   5   4   4  -2  -2  -3
#   -3   1  -4   1  13   2  14  -1   4   2  -3  -1 -14 -17  -3  -2  -6  -3
#    1   1   2   4  -1  -2  -2  -2 -13  -1   0  -3  -3 -13  -7 -11   0   1
#    7  -2   4 -15  -4 -15  -2 -15  -6  -1   4  -6  14   6   5   5   4   4
#   -3   1  -2   9  11   3   3  14  12   2  -3   8 -10   5   1   0  -6   4
#   -2   1   3   1   9   1  -6  -5  10   2   2   0   2   4 -14 -10  -4 -12
#   10   1   2   0  -1  -6   4  -6  -2  -3  -5  -3   3  -2  -5   0  -3  -4
#    2   1  -3   2   3  -3  -3   0  -4   4  -4   3   3   0   2   1  -1  -2
#    7  -2  -6  -2  -4   6  -6  -2   3  -2 -10   1  -3  -2  -2   0   5  -2
#    0   0   2  12   3  11   1   7   2   3   6  -5  -3   6   1   2  -5   0
#    4   3   3  -2  14  -3  10   8   8   8   6   1   3  -9  -4   9   5  -1
#   -2   3   0   3  -2   7  -4 -10   1   6  -6  13 -11  -9   2   0  -3  -4
#   -1   4   1   8   7  -3  -9   3  -4   5  -1  -6   2   7   1   0  -4  -2
#    0  -9 -11 -14   1   1  10  -3   2   4  -5   0   2  -2   0   1  -1  -1
#   -1   0  10   8  -8  -8   0   8  -6   0  -5  -3]
# With MSE 34.61666666666667
# With MAE 4.41
#
# Model CNN/CNN_v0/weights/cnn_v0_40_1e_7_40_2 behaved:
# For cut-of-point 0.2 had accuracy 84.0987293624227:
# [ -2  14   1   7   7  13  -5  -5  -6  -1  -2   0  -3   2  -1   5  11   1
#    0   4   3  -2  -5  -4  -1  -7  -1   7   0   1   6  -5  -2   0   4   2
#   17   4  19  10   5   3  12   2   6   6  18  16   6   8   2   0   1   0
#   -6   1  -2   3  17   2  18   6   8  -1  -4  -2 -11 -11   2  -3  -7   1
#    3   4   7   4   0   4   0  -1 -11   3   4   0  -3 -11  -6  -9   3   1
#   11  -3   6 -13  -1 -16  -2 -15  -6   1   6  -5  15   8   7   7   6   6
#    3   4  -2  12   9   7   4  21  13   5  -2   8  -9   7   1   0  -3   5
#    3   3   6   5  17   6  -1  -1  15   3   9   2   1   3 -13 -11   0 -10
#   10   1   1   0  -1  -5   5  -2   1   4  -3  -2   2  -2  -1   1  -4  -2
#    4   1  -1   6   6  -4  -4   0  -2   7  -5   7   8   3   3   2   1  -1
#    3  -4  -6   0  -4  11  -6  -1   8   1  -8   3   0   0  -4   1   4   0
#    2  -1   5  10   6  12   0   3   4   4   8  -5   0   7   2   2  -3   4
#    4   8   4   4  17  -2   6   6   8   9   6   5   5  -8   1   8   4  -2
#   -2   3   4   3  -3   8  -4  -5   4   8  -5  18 -14  -3   5   2  -3  -5
#    1   3   2   7   7  -3  -7   6  -3   2  -1  -5   5  11   2   4  -4   0
#   -1  -5 -14 -12   1   1  10  -3   6  12  -4   3   3  -1   2   3   1  -1
#    1   0   8   9  -8  -4   0   8  -3  -1  -2  -1]
# With MSE 42.00333333333333
# With MAE 4.91
#
# Model CNN/CNN_v0/weights/cnn_v0_40_1e_8_30_2 behaved:
# For cut-of-point 0.2 had accuracy 84.63102413804954:
# [ -1  12   1   9   5  10  -4  -6  -5  -2  -4  -1  -3  -1  -2   7   7   3
#   -2   3   1  -1  -5  -4   2  -8  -2   6   0   2   5  -4   1   1   3   6
#   12   3  21  11   6   2   9   2   7   6  15  18   6   8   4   0   0   3
#   -6   2  -3   2  19   4  15   2   7  -2  -1   0 -10 -13  -4   2  -7   0
#    4   2   5   6   1   3  -1   0 -10   4   1   1   0 -11  -7  -9   2   2
#   12  -4   4 -10  -2 -14   0 -15  -3  -1   7  -6  12   9   3   6   4   6
#    1   3  -4  12   8   5   2  14  11   0  -6  10 -11   3   1  -4  -7   6
#    0   0   5   7  15   8  -2   2  14   4  11   2   2   3 -13  -8  -4  -9
#   10   2  -1   2  -2  -5   4  -4   2   3  -4  -4   2   3  -3   0  -4  -2
#    2   2   0   5   3  -2  -4   0  -2   7  -3   5   5   3   2   0   0   1
#    5  -4  -2  -3  -3   8  -5  -2  10   1 -10   2  -2   0  -1  -2   6   1
#    2   0   6   9   4  11   0   5   3   3   8  -5   2   7   1   2  -6   0
#    4   4   4   2  20  -3   1   7   3   6   4   4   6  -9  -3   6   4  -1
#   -2   1   2   5  -4   7  -3  -4   5   6  -9  13 -11  -5   0   1  -4  -5
#   -1   1   1   6   4  -3  -8   5  -4   4  -5  -7   4   6   2   4  -5  -2
#   -1  -9 -16 -14   0  -1   8  -4   7  10  -3   4   3  -5   1   2  -3  -2
#    2   0   6  10  -7  -6  -3   7  -2  -2  -3  -1]
# With MSE 37.63666666666666
# With MAE 4.703333333333333
