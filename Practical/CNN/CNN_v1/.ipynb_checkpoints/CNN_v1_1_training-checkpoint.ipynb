# %%
# %cd ../../
# Out:
# /home/PJWSTK/s14028/Engine

# %%
import keras

from common import *

from CNN.CNN_v1_1 import CNN_v1_1
# Out:
# Using TensorFlow backend.

# %%
train, test = data_sets()
image_tensors = train[0], test[0]
person_coo_tensors = train[1], test[1]
count_matrix = train[2], test[2]

image_train, image_test = image_tensors
person_coo_train, person_coo_test = person_coo_tensors
count_train, count_test = count_matrix
count_train = count_train.astype(np.uint16)
count_test = count_test.astype(np.uint16)

# %%
cnn_v1_1 = CNN_v1_1((480, 640, 3), split_into_parts=20)
cnn_v1_1.def_model()

# %%
images = cnn_v1_1._prepare_images(image_train)
anwsers = cnn_v1_1._prepare_anwsers(person_coo_train)

# %%
history = cnn_v1_1.model.fit(images[:1], anwsers[:1])
# Out:
# Epoch 1/1
# 1/1 [==============================] - 2s 2s/step - loss: 1.9768 - acc: 1.0000

# %%
parallel_model = keras.utils.multi_gpu_model(
        cnn_v1_1.model,
        gpus=6,
        cpu_merge=False)
parallel_model.compile(
        loss="binary_crossentropy", 
        optimizer="adam", 
        metrics=["accuracy"])

# %%
parallel_model.optimizer.lr.assign(1e-1)
# Out:
# <tf.Tensor 'Assign:0' shape=() dtype=float32_ref>

# %%
parallel_model.fit(images, anwsers, batch_size=35000, epochs=25,
                   validation_split=0.1)
# Out:
# Train on 612000 samples, validate on 68000 samples
# Epoch 1/25
# 612000/612000 [==============================] - 43s 71us/step - loss: 21574.8554 - acc: 0.5109 - val_loss: 10271.4270 - val_acc: 0.6851
# Epoch 2/25
# 612000/612000 [==============================] - 31s 51us/step - loss: 9037.6508 - acc: 0.5586 - val_loss: 6349.6364 - val_acc: 0.7423
# Epoch 3/25
# 612000/612000 [==============================] - 31s 50us/step - loss: 5400.7974 - acc: 0.6320 - val_loss: 3508.0953 - val_acc: 0.9320
# Epoch 4/25
# 612000/612000 [==============================] - 31s 51us/step - loss: 3712.8148 - acc: 0.7497 - val_loss: 2530.2191 - val_acc: 0.9310
# Epoch 5/25
# 612000/612000 [==============================] - 32s 52us/step - loss: 2684.1438 - acc: 0.8458 - val_loss: 1751.1041 - val_acc: 0.9310
# Epoch 6/25
# 612000/612000 [==============================] - 32s 52us/step - loss: 1979.4799 - acc: 0.8850 - val_loss: 1301.7203 - val_acc: 0.9310
# Epoch 7/25
# ...

# %%
parallel_model.save_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_1_25")

# %%
parallel_model.load_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_1_25")

# %%
parallel_model.fit(images, anwsers, batch_size=35000, epochs=25,
                   validation_split=0.1)
# Out:
# Train on 612000 samples, validate on 68000 samples
# Epoch 1/25
# 612000/612000 [==============================] - 31s 51us/step - loss: 23.4600 - acc: 0.9321 - val_loss: 15.6164 - val_acc: 0.9310
# Epoch 2/25
# 612000/612000 [==============================] - 30s 49us/step - loss: 21.0114 - acc: 0.9321 - val_loss: 14.3874 - val_acc: 0.9310
# Epoch 3/25
# 612000/612000 [==============================] - 31s 51us/step - loss: 18.9135 - acc: 0.9321 - val_loss: 13.2938 - val_acc: 0.9310
# Epoch 4/25
# 612000/612000 [==============================] - 31s 50us/step - loss: 17.1170 - acc: 0.9321 - val_loss: 12.3279 - val_acc: 0.9310
# Epoch 5/25
# 612000/612000 [==============================] - 31s 50us/step - loss: 15.5857 - acc: 0.9321 - val_loss: 11.4727 - val_acc: 0.9310
# Epoch 6/25
# 612000/612000 [==============================] - 30s 49us/step - loss: 14.2488 - acc: 0.9321 - val_loss: 10.6968 - val_acc: 0.9310
# Epoch 7/25
# ...

# %%
parallel_model.save_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_1_50")

# %%
parallel_model.load_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_1_50")

# %%
parallel_model.fit(images, anwsers, batch_size=35000, epochs=25,
                   validation_split=0.1)
# Out:
# Train on 612000 samples, validate on 68000 samples
# Epoch 1/25
# 612000/612000 [==============================] - 30s 50us/step - loss: 4.0507 - acc: 0.9322 - val_loss: 3.5802 - val_acc: 0.9310
# Epoch 2/25
# 612000/612000 [==============================] - 30s 49us/step - loss: 3.8744 - acc: 0.9321 - val_loss: 3.4343 - val_acc: 0.9310
# Epoch 3/25
# 612000/612000 [==============================] - 30s 50us/step - loss: 3.7105 - acc: 0.9322 - val_loss: 3.2991 - val_acc: 0.9310
# Epoch 4/25
# 612000/612000 [==============================] - 30s 50us/step - loss: 3.5626 - acc: 0.9322 - val_loss: 3.1724 - val_acc: 0.9310
# Epoch 5/25
# 612000/612000 [==============================] - 31s 50us/step - loss: 3.4200 - acc: 0.9322 - val_loss: 3.0474 - val_acc: 0.9310
# Epoch 6/25
# 612000/612000 [==============================] - 30s 50us/step - loss: 3.2898 - acc: 0.9322 - val_loss: 2.9330 - val_acc: 0.9310
# Epoch 7/25
# ...

# %%
parallel_model.save_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_1_75")

# %%
parallel_model.load_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_1_75")

# %%
parallel_model.optimizer.lr.assign(1e-3)
# Out:
# <tf.Tensor 'Assign_1:0' shape=() dtype=float32_ref>

# %%
parallel_model.fit(images, anwsers, batch_size=35000, epochs=10,
                   validation_split=0.1)
# Out:
# Train on 612000 samples, validate on 68000 samples
# Epoch 1/10
# 612000/612000 [==============================] - 31s 51us/step - loss: 1.8560 - acc: 0.9322 - val_loss: 1.6797 - val_acc: 0.9310
# Epoch 2/10
# 612000/612000 [==============================] - 31s 50us/step - loss: 1.8142 - acc: 0.9322 - val_loss: 1.6445 - val_acc: 0.9310
# Epoch 3/10
# 612000/612000 [==============================] - 31s 50us/step - loss: 1.7748 - acc: 0.9322 - val_loss: 1.6104 - val_acc: 0.9310
# Epoch 4/10
# 612000/612000 [==============================] - 32s 52us/step - loss: 1.7398 - acc: 0.9322 - val_loss: 1.5785 - val_acc: 0.9310
# Epoch 5/10
# 612000/612000 [==============================] - 33s 54us/step - loss: 1.7044 - acc: 0.9322 - val_loss: 1.5475 - val_acc: 0.9310
# Epoch 6/10
# 612000/612000 [==============================] - 32s 53us/step - loss: 1.6705 - acc: 0.9322 - val_loss: 1.5170 - val_acc: 0.9310
# Epoch 7/10
# ...

# %%
parallel_model.save_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_3_10")

# %%
parallel_model.load_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_3_10")

# %%
parallel_model.fit(images, anwsers, batch_size=35000, epochs=40,
                   validation_split=0.1)
# Out:
# Train on 612000 samples, validate on 68000 samples
# Epoch 1/40
# 612000/612000 [==============================] - 32s 52us/step - loss: 1.5201 - acc: 0.9322 - val_loss: 1.3872 - val_acc: 0.9310
# Epoch 2/40
# 612000/612000 [==============================] - 33s 53us/step - loss: 1.4949 - acc: 0.9322 - val_loss: 1.3640 - val_acc: 0.9310
# Epoch 3/40
# 612000/612000 [==============================] - 32s 52us/step - loss: 1.4690 - acc: 0.9322 - val_loss: 1.3417 - val_acc: 0.9310
# Epoch 4/40
# 612000/612000 [==============================] - 33s 54us/step - loss: 1.4427 - acc: 0.9322 - val_loss: 1.3203 - val_acc: 0.9310
# Epoch 5/40
# 612000/612000 [==============================] - 31s 51us/step - loss: 1.4171 - acc: 0.9322 - val_loss: 1.2993 - val_acc: 0.9310
# Epoch 6/40
# 612000/612000 [==============================] - 32s 52us/step - loss: 1.3956 - acc: 0.9322 - val_loss: 1.2791 - val_acc: 0.9310
# Epoch 7/40
# ...

# %%
parallel_model.save_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_3_50")

# %%
parallel_model.load_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_3_50")

# %%
parallel_model.fit(images, anwsers, batch_size=35000, epochs=50,
                   validation_split=0.1)
# Out:
# Train on 612000 samples, validate on 68000 samples
# Epoch 1/50
# 612000/612000 [==============================] - 33s 53us/step - loss: 0.8714 - acc: 0.9322 - val_loss: 0.8193 - val_acc: 0.9310
# Epoch 2/50
# 612000/612000 [==============================] - 31s 51us/step - loss: 0.8621 - acc: 0.9322 - val_loss: 0.8102 - val_acc: 0.9310
# Epoch 3/50
# 612000/612000 [==============================] - 32s 52us/step - loss: 0.8524 - acc: 0.9322 - val_loss: 0.8024 - val_acc: 0.9310
# Epoch 4/50
# 612000/612000 [==============================] - 32s 52us/step - loss: 0.8429 - acc: 0.9322 - val_loss: 0.7939 - val_acc: 0.9310
# Epoch 5/50
# 612000/612000 [==============================] - 33s 54us/step - loss: 0.8345 - acc: 0.9322 - val_loss: 0.7857 - val_acc: 0.9310
# Epoch 6/50
# 612000/612000 [==============================] - 31s 51us/step - loss: 0.8252 - acc: 0.9322 - val_loss: 0.7776 - val_acc: 0.9310
# Epoch 7/50
# ...

# %%
parallel_model.save_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_3_100")

# %%
parallel_model.load_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_3_100")

# %%
parallel_model.fit(images, anwsers, batch_size=35000, epochs=50,
                   validation_split=0.1)
# Out:
# Train on 612000 samples, validate on 68000 samples
# Epoch 1/50
# 612000/612000 [==============================] - 31s 51us/step - loss: 0.5527 - acc: 0.9322 - val_loss: 0.5269 - val_acc: 0.9310
# Epoch 2/50
# 612000/612000 [==============================] - 31s 51us/step - loss: 0.5487 - acc: 0.9322 - val_loss: 0.5234 - val_acc: 0.9310
# Epoch 3/50
# 612000/612000 [==============================] - 32s 52us/step - loss: 0.5450 - acc: 0.9322 - val_loss: 0.5200 - val_acc: 0.9310
# Epoch 4/50
# 612000/612000 [==============================] - 32s 52us/step - loss: 0.5411 - acc: 0.9322 - val_loss: 0.5167 - val_acc: 0.9310
# Epoch 5/50
# 612000/612000 [==============================] - 32s 51us/step - loss: 0.5373 - acc: 0.9322 - val_loss: 0.5132 - val_acc: 0.9310
# Epoch 6/50
# 612000/612000 [==============================] - 31s 50us/step - loss: 0.5336 - acc: 0.9322 - val_loss: 0.5099 - val_acc: 0.9310
# Epoch 7/50
# ...

# %%
parallel_model.save_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_3_150")

# %%
parallel_model.load_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_3_150")

# %%
parallel_model.fit(images, anwsers, batch_size=35000, epochs=50,
                   validation_split=0.1)
# Out:
# Train on 612000 samples, validate on 68000 samples
# Epoch 1/50
# 612000/612000 [==============================] - 32s 52us/step - loss: 0.4146 - acc: 0.9322 - val_loss: 0.4036 - val_acc: 0.9310
# Epoch 2/50
# 612000/612000 [==============================] - 32s 53us/step - loss: 0.4129 - acc: 0.9322 - val_loss: 0.4020 - val_acc: 0.9310
# Epoch 3/50
# 612000/612000 [==============================] - 31s 51us/step - loss: 0.4114 - acc: 0.9322 - val_loss: 0.4005 - val_acc: 0.9310
# Epoch 4/50
# 612000/612000 [==============================] - 31s 51us/step - loss: 0.4093 - acc: 0.9322 - val_loss: 0.3990 - val_acc: 0.9310
# Epoch 5/50
# 612000/612000 [==============================] - 32s 52us/step - loss: 0.4075 - acc: 0.9322 - val_loss: 0.3975 - val_acc: 0.9310
# Epoch 6/50
# 612000/612000 [==============================] - 32s 52us/step - loss: 0.4060 - acc: 0.9322 - val_loss: 0.3959 - val_acc: 0.9310
# Epoch 7/50
# ...

# %%
parallel_model.save_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_3_200")

# %%
parallel_model.load_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_3_200")

# %%
parallel_model.fit(images, anwsers, batch_size=35000, epochs=100,
                   validation_split=0.1)
# Out:
# Train on 612000 samples, validate on 68000 samples
# Epoch 1/100
# 612000/612000 [==============================] - 30s 49us/step - loss: 0.3506 - acc: 0.9322 - val_loss: 0.3471 - val_acc: 0.9310
# Epoch 2/100
# 612000/612000 [==============================] - 30s 48us/step - loss: 0.3496 - acc: 0.9322 - val_loss: 0.3463 - val_acc: 0.9310
# Epoch 3/100
# 612000/612000 [==============================] - 30s 48us/step - loss: 0.3488 - acc: 0.9322 - val_loss: 0.3455 - val_acc: 0.9310
# Epoch 4/100
# 612000/612000 [==============================] - 31s 51us/step - loss: 0.3480 - acc: 0.9322 - val_loss: 0.3448 - val_acc: 0.9310
# Epoch 5/100
# 612000/612000 [==============================] - 30s 49us/step - loss: 0.3472 - acc: 0.9322 - val_loss: 0.3440 - val_acc: 0.9310
# Epoch 6/100
# 612000/612000 [==============================] - 30s 49us/step - loss: 0.3464 - acc: 0.9322 - val_loss: 0.3433 - val_acc: 0.9310
# Epoch 7/100
# ...

# %%
parallel_model.save_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_3_300")

# %%
parallel_model.load_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_3_300")

# %%
parallel_model.fit(images, anwsers, batch_size=35000, epochs=100,
                   validation_split=0.1)
# Out:
# Train on 612000 samples, validate on 68000 samples
# Epoch 1/100
# 612000/612000 [==============================] - 27s 45us/step - loss: 0.2801 - acc: 0.9322 - val_loss: 0.2761 - val_acc: 0.9310
# Epoch 2/100
# 612000/612000 [==============================] - 14s 22us/step - loss: 0.2716 - acc: 0.9322 - val_loss: 0.2739 - val_acc: 0.9310
# Epoch 3/100
# 612000/612000 [==============================] - 14s 23us/step - loss: 0.2701 - acc: 0.9322 - val_loss: 0.2728 - val_acc: 0.9310
# Epoch 4/100
# 612000/612000 [==============================] - 14s 23us/step - loss: 0.2691 - acc: 0.9322 - val_loss: 0.2720 - val_acc: 0.9310
# Epoch 5/100
# 612000/612000 [==============================] - 14s 23us/step - loss: 0.2684 - acc: 0.9322 - val_loss: 0.2714 - val_acc: 0.9310
# Epoch 6/100
# 612000/612000 [==============================] - 14s 23us/step - loss: 0.2678 - acc: 0.9322 - val_loss: 0.2708 - val_acc: 0.9310
# Epoch 7/100
# ...

# %%
parallel_model.save_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_3_400")

# %%
parallel_model.load_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_3_400")

# %%
parallel_model.fit(images, anwsers, batch_size=35000, epochs=50,
                   validation_split=0.1)
# Out:
# Train on 612000 samples, validate on 68000 samples
# Epoch 1/50
# 612000/612000 [==============================] - 14s 23us/step - loss: 0.2615 - acc: 0.9322 - val_loss: 0.2648 - val_acc: 0.9310
# Epoch 2/50
# 612000/612000 [==============================] - 14s 23us/step - loss: 0.2614 - acc: 0.9322 - val_loss: 0.2647 - val_acc: 0.9310
# Epoch 3/50
# 612000/612000 [==============================] - 14s 23us/step - loss: 0.2614 - acc: 0.9322 - val_loss: 0.2648 - val_acc: 0.9310
# Epoch 4/50
# 612000/612000 [==============================] - 14s 23us/step - loss: 0.2614 - acc: 0.9322 - val_loss: 0.2647 - val_acc: 0.9310
# Epoch 5/50
# 612000/612000 [==============================] - 13s 22us/step - loss: 0.2614 - acc: 0.9322 - val_loss: 0.2647 - val_acc: 0.9310
# Epoch 6/50
# 612000/612000 [==============================] - 13s 22us/step - loss: 0.2614 - acc: 0.9322 - val_loss: 0.2647 - val_acc: 0.9310
# Epoch 7/50
# ...

# %%
parallel_model.fit(images, anwsers, batch_size=35000, epochs=50,
                   validation_split=0.1)
# Out:
# Train on 612000 samples, validate on 68000 samples
# Epoch 1/50
# 612000/612000 [==============================] - 14s 23us/step - loss: 0.2610 - acc: 0.9322 - val_loss: 0.2643 - val_acc: 0.9310
# Epoch 2/50
# 612000/612000 [==============================] - 13s 22us/step - loss: 0.2610 - acc: 0.9322 - val_loss: 0.2643 - val_acc: 0.9310
# Epoch 3/50
# 612000/612000 [==============================] - 14s 22us/step - loss: 0.2610 - acc: 0.9322 - val_loss: 0.2643 - val_acc: 0.9310
# Epoch 4/50
# 612000/612000 [==============================] - 14s 22us/step - loss: 0.2610 - acc: 0.9322 - val_loss: 0.2643 - val_acc: 0.9310
# Epoch 5/50
# 612000/612000 [==============================] - 14s 22us/step - loss: 0.2610 - acc: 0.9322 - val_loss: 0.2643 - val_acc: 0.9310
# Epoch 6/50
# 612000/612000 [==============================] - 14s 22us/step - loss: 0.2609 - acc: 0.9322 - val_loss: 0.2643 - val_acc: 0.9310
# Epoch 7/50
# ...

# %%
parallel_model.save_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_3_500")

# %%
parallel_model.load_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_3_500")

# %%
parallel_model.optimizer.lr.assign(1)
# Out:
# <tf.Tensor 'Assign_37:0' shape=() dtype=float32_ref>

# %%
parallel_model.fit(images, anwsers, batch_size=35000, epochs=10,
                   validation_split=0.1)
# Out:
# Train on 612000 samples, validate on 68000 samples
# Epoch 1/10
# 612000/612000 [==============================] - 14s 23us/step - loss: 0.2607 - acc: 0.9322 - val_loss: 0.2640 - val_acc: 0.9310
# Epoch 2/10
# 612000/612000 [==============================] - 14s 22us/step - loss: 0.2607 - acc: 0.9322 - val_loss: 0.2640 - val_acc: 0.9310
# Epoch 3/10
# 612000/612000 [==============================] - 14s 23us/step - loss: 0.2607 - acc: 0.9322 - val_loss: 0.2640 - val_acc: 0.9310
# Epoch 4/10
# 612000/612000 [==============================] - 14s 23us/step - loss: 0.2607 - acc: 0.9322 - val_loss: 0.2640 - val_acc: 0.9310
# Epoch 5/10
# 612000/612000 [==============================] - 14s 22us/step - loss: 0.2607 - acc: 0.9322 - val_loss: 0.2640 - val_acc: 0.9310
# Epoch 6/10
# 612000/612000 [==============================] - 13s 22us/step - loss: 0.2607 - acc: 0.9322 - val_loss: 0.2640 - val_acc: 0.9310
# Epoch 7/10
# ...

# %%
parallel_model.fit(images, anwsers, batch_size=35000, epochs=40,
                   validation_split=0.1)
# Out:
# Train on 612000 samples, validate on 68000 samples
# Epoch 1/40
# 612000/612000 [==============================] - 14s 23us/step - loss: 0.2606 - acc: 0.9322 - val_loss: 0.2640 - val_acc: 0.9310
# Epoch 2/40
# 612000/612000 [==============================] - 14s 22us/step - loss: 0.2606 - acc: 0.9322 - val_loss: 0.2640 - val_acc: 0.9310
# Epoch 3/40
# 612000/612000 [==============================] - 14s 22us/step - loss: 0.2606 - acc: 0.9322 - val_loss: 0.2640 - val_acc: 0.9310
# Epoch 4/40
# 612000/612000 [==============================] - 13s 22us/step - loss: 0.2606 - acc: 0.9322 - val_loss: 0.2639 - val_acc: 0.9310
# Epoch 5/40
# 612000/612000 [==============================] - 14s 22us/step - loss: 0.2606 - acc: 0.9322 - val_loss: 0.2639 - val_acc: 0.9310
# Epoch 6/40
# 612000/612000 [==============================] - 14s 23us/step - loss: 0.2606 - acc: 0.9322 - val_loss: 0.2640 - val_acc: 0.9310
# Epoch 7/40
# ...

# %%
parallel_model.fit(images, anwsers, batch_size=35000, epochs=100,
                   validation_split=0.1)
# Out:
# Train on 612000 samples, validate on 68000 samples
# Epoch 1/100
# 612000/612000 [==============================] - 14s 23us/step - loss: 0.2605 - acc: 0.9322 - val_loss: 0.2638 - val_acc: 0.9310
# Epoch 2/100
# 612000/612000 [==============================] - 14s 22us/step - loss: 0.2605 - acc: 0.9322 - val_loss: 0.2638 - val_acc: 0.9310
# Epoch 3/100
# 612000/612000 [==============================] - 14s 22us/step - loss: 0.2605 - acc: 0.9322 - val_loss: 0.2638 - val_acc: 0.9310
# Epoch 4/100
# 612000/612000 [==============================] - 14s 22us/step - loss: 0.2605 - acc: 0.9322 - val_loss: 0.2638 - val_acc: 0.9310
# Epoch 5/100
# 612000/612000 [==============================] - 14s 22us/step - loss: 0.2605 - acc: 0.9322 - val_loss: 0.2638 - val_acc: 0.9310
# Epoch 6/100
# 612000/612000 [==============================] - 14s 23us/step - loss: 0.2605 - acc: 0.9322 - val_loss: 0.2638 - val_acc: 0.9310
# Epoch 7/100
# ...

# %%
parallel_model.save_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_0_150")

# %%
parallel_model.load_weights("CNN/CNN_v1/weights/cnn_v1_1_1e_0_150")
