# %%
# %cd ../../
# Out:
# /home/PJWSTK/s14028/Engine

# %%
import keras

from common import *
from testing import test_model
from testing import best_cop_diff
from testing import mse
from testing import mae

from CNN.CNN_v1 import CNN_v1
# Out:
# Using TensorFlow backend.

# %%
train, test = data_sets()
image_tensors = train[0], test[0]
person_coo_tensors = train[1], test[1]
count_matrix = train[2], test[2]

image_train, image_test = image_tensors
person_coo_train, person_coo_test = person_coo_tensors
count_train, count_test = count_matrix
count_train = count_train.astype(np.uint16)
count_test = count_test.astype(np.uint16)

# %%
cnn = CNN_v1((480, 640, 3), split_into_parts=20)

images = cnn._prepare_images(image_test)
anwsers = cnn._prepare_anwsers(person_coo_test)

# %%
cop = np.linspace(0, 1, 11)[1:-1]

# %%
prefix = "CNN/CNN_v0/weights/"

# %%
model_names = ["cnn_v1_1e_1_75",
          "cnn_v1_1e_3_30",
          "cnn_v1_1e_5_20",
          "cnn_v1_1e_5_40",
          "cnn_v1_1e_5_42",
          "cnn_v1_1e_6_1",
          "cnn_v1_1e_6_21",
          "cnn_v1_1e_6_30"]

model_names = [prefix + name for name in model_names]

# %%
models = [CNN_v1((480, 640, 3), split_into_parts=20) for i in range(len(model_names))]

# %%
results = {}

for model_name, model in zip(model_names, models):
  model.def_model()
  model.model.fit(images[:1], anwsers[:1])
  
  model.model = keras.utils.multi_gpu_model(model.model, gpus=6, cpu_merge=False)
  model.model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
  
  model.model.load_weights(model_name)
  
  results[model_name] = test_model(model=model, images=image_test, counts=count_test, cut_of_points=cop)
# Out:
# Epoch 1/1
# 1/1 [==============================] - 2s 2s/step - loss: 0.6942 - acc: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 2s 2s/step - loss: 0.6948 - acc: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 2s 2s/step - loss: 0.6940 - acc: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 2s 2s/step - loss: 0.6941 - acc: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 3s 3s/step - loss: 0.6945 - acc: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 4s 4s/step - loss: 0.6942 - acc: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 4s 4s/step - loss: 0.6942 - acc: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 4s 4s/step - loss: 0.6942 - acc: 1.0000

# %%
for name, result in results.items():
  diff = best_cop_diff(result, count_test)
  
  print(f"Model {name} behaved:")
  
  print(f"For cut-of-point {diff[0]} had accuracy {diff[1]}:")
  print(diff[2])
  
  print(f"With MSE {mse(diff[2])}")
  print(f"With MAE {mae(diff[2])}", end="\n\n")
# Out:
# Model cnn_v1_1e_1_75 behaved:
# [0.2, 73.01238189574596, array([-14, -12, -12, -12,  -9,  -4, -11, -13,  -3,  -4,  -2,  -1,  -6,
#         -4,  -4,  -5,  -5,  -5,  -8,  -5,  -5,  -1,  -6,  -8,  -9,  -8,
#        -10,  -6,   1,  -3,  -4, -11, -14,  -6,   0,  -3,  -4,  -3,  -2,
#         -9,  -5,  -7,  -2,  -4,  -1,  -7,  -5,  -9,  -6,  -3,  -9,  -7,
#         -9, -10,  -7,  -8, -12, -13, -10, -21, -11, -21, -19, -19,  -5,
#        -11, -14, -22, -25,  -7, -10, -10,  -7,  -7,  -9,  -6, -10, -11,
#         -6, -11,  -8,  -8,  -9,  -4,  -8, -12,  -7,  -6,  -4,  -6,  -5,
#         -9,  -3, -21, -16, -22, -16, -16,  -9, -12, -11,  -7,  -6,  -7,
#          2,  -6, -12, -12, -19,  -5, -10,  -9, -15, -14, -15,  -6,  -7,
#         -5,  -6,  -6, -13,  -6,  -8,  -8, -10,  -4, -10,  -7, -11,  -5,
#         -2, -10, -11,  -9, -15, -10,  -6, -10,  -9,  -8,  -4, -13, -10,
#        -15, -10, -10, -12,  -3,  -7,  -6,  -6,  -9,  -8, -13, -11, -17,
#         -3, -14,  -4,  -3,  -9, -14,  -9,  -7,  -7,  -5,  -5,  -5, -10,
#          0,  -5,  -9,  -3,  -4,  -4, -12,  -9,  -2,  -2,  -1,  -4,  -9,
#         -7,  -5,  -7,  -7, -12, -11,  -5,   0, -12,  -8, -13, -10,  -5,
#         -8,  -7,  -5,  -4, -12,  -4,  -2,  -8,  -2,   0,  -5,  -4, -12,
#         -7, -15, -11, -13, -13, -17, -17,  -8, -10,  -5,  -5,  -6,   0,
#         -8,  -7, -11,  -3,  -2,   0,  -5, -11, -18, -17, -17, -17, -13,
#         -8,  -9,  -9,  -9, -14, -10, -17, -18, -18, -16, -18,  -7, -17,
#        -15, -13,  -5,  -9, -11,  -7,  -6, -12,  -9, -12,  -7,  -9,  -9,
#        -12, -11,  -4, -15,  -9, -12, -12, -11, -11, -15, -14, -17, -14,
#        -22,  -8, -10,  -6,  -7,  -6,  -6,  -7,  -6,  -8, -11, -13,  -1,
#         -1,  -6,  -8,  -4,  -6,  -1, -14,  -1,  -8, -11,  -8,  -8,  -7,
#         -9], dtype=int32)]
# With MSE 97.57
# With MAE 8.663333333333334
#
# Model cnn_v1_1e_3_30 behaved:
# [0.30000000000000004, 86.03807424366889, array([ -3,  -7,  -6, -10,  -7,   2,  -8,  -6,   2,  -4,   0,  -1,  -6,
#          1,  -3,  -2,  -1,  -6,   1,   0,  -4,   4,  -2,  -7,  -3,  -2,
#         -4,   1,   1,   0,  -2,  -6,  -7,  -1,   0,  -2,   4,   5,  -4,
#         -3,   2,  -4,  -1,  -2,   0,   1,   0,  -3,  -2,   3,  -3,  -4,
#         -2,  -5,  -5,  -2,  -5,  -5, -11, -14,  -4, -12,  -9,  -6,   1,
#         -5,  -6, -12, -16,  -1,  -7,  -2,  -3,  -1,  -2,  -3,  -2,  -6,
#          1,   1,  -1,  -2,  -9,  -2,  -5,  -6,  -1,  -4,   1,  -4,  -3,
#         -3,  -1, -15, -10, -13,  -6, -15,  -3,   0,  -5,  -2,   1,  -2,
#          7,   2,  -6,  -5,  -5,   0,  -4,  -4,  -8,  -6,  -5,   6,  -1,
#          7,  -1,  -3,  -4,  -1,  -1,   0,  -5,   1,   2,  -4,  -7,   7,
#          1,  -4,  -5,  -3,  -5,  -2,   2,  -2,  -4,  -2,   6,  -8,   1,
#         -3,   0,  -5,  -4,   5,  -6,  -4,  -1,  -4,  -1, -11,  -7,  -8,
#         -4, -10,   4,   2,  -6,  -6,  -5,   1,  -3,  -5,  -1,  -3,  -8,
#          2,   0,  -8,   0,   1,   5,  -8,   0,  -1,   2,   0,  -2,  -7,
#         -6,   1,  -4,  -2,  -4,  -6,  -7,  -2, -12,  -5,  -6,  -8,  -7,
#         -5,  -7,  -2,  -2,  -3,  -2,  -2,  -4,   1,  -1,   0,  -2,  -2,
#         -6, -10,  -7,  -5, -11,  -8, -11,  -4,   0,   3,   0,  -4,   3,
#         -4,  -8,  -6, -11,  -1,   2,  -3,  -6,  -8, -11,  -7,  -8,  -5,
#         -3,  -6,  -7,  -8,  -6,  -8, -12,  -3, -10,  -8,  -6,   2,  -9,
#        -12,  -5,  -1,  -7,  -3,  -7,  -3,  -5,  -5, -11,  -6, -10,   2,
#         -9,  -5,   3,  -9,  -4,  -5, -10,  -3,  -8, -10,  -6,  -9,  -7,
#        -16,   0,  -3,   3,  -4,  -4,   3,  -5,   0,   1,  -8,  -6,   6,
#          3,  -1,  -4,  -4,  -3,   1,  -3,  -4,  -5,  -3,  -6,  -2,  -3,
#         -6], dtype=int32)]
# With MSE 30.71
# With MAE 4.47
#
# Model cnn_v1_1e_5_20 behaved:
# [0.30000000000000004, 88.7345948008066, array([  7,  -3,   1,  -1,  -2,   8,  -7,  -3,   6,   1,   5,   3,  -1,
#          2,   2,  -1,   2,  -5,   4,   3,  -1,   9,   4,  -4,   0,  -3,
#         -3,   4,   2,   4,   0,  -5,  -7,  -1,   4,   3,  10,   3,   0,
#          0,   6,   2,   5,   1,   3,   0,   6,   1,   3,   6,  -1,   0,
#          1,  -3,  -3,  -3,  -2,   5,  -3, -10,   4,  -7,  -6,  -2,   5,
#          0,  -3,  -2, -12,   4,  -1,   0,   1,   7,   1,   0,   2,  -2,
#          3,   1,   6,   3,  -7,  -2,   0,  -4,  -1,  -2,   2,  -4,   1,
#          4,   2,  -7,  -5,  -4,   0,  -7,   1,   2,   1,   3,   2,   2,
#          8,   6,  -4,  -1,   1,   3,   5,   0,  -3,   4,   2,  11,   2,
#         12,   5,   1,  -5,   2,   9,   8,   0,   8,   7,   1,  -6,   9,
#          3,   2,  -2,   3,   5,   2,   4,   3,   2,   3,   6,   1,   8,
#          1,   6,   6,   0,  13,  -3,   2,   5,  -1,   0,  -7,  -1,  -2,
#         -1,  -4,   8,   5,   0,  -1,   0,   4,   0,   1,   3,   1,  -5,
#          3,   0,  -5,   3,   5,   3,  -2,   3,   2,   5,   1,  -3,  -4,
#          1,   4,  -2,   2,   2,   5,  -1,   4,  -6,  -1,   3,  -3,  -5,
#         -3,   0,   2,   6,   0,  -1,  -1,   0,   8,   3,   0,   0,   0,
#         -2,  -6,  -2,  -3,  -9,  -5,  -7,  -5,   5,   7,   6,   2,   3,
#         -2,   0,   8,  -3,   5,   5,   6,   1,  -3,  -6,  -1,  -1,   1,
#         -2,  -1,  -6,  -6,   3,  -1,  -9,  -1,  -5,   1,   4,   5,  -4,
#         -2,   2,   4,  -3,  -1,  -2,  -1,  -2,   2,  -7,  -2,  -7,   5,
#         -4,  -1,   4,  -4,   0,   1,  -5,  -6,  -7,  -3,  -1,  -1,  -2,
#        -13,   5,   5,   5,   4,   5,  12,   0,   3,   6,  -6,   1,   9,
#          3,   2,   3,  -5,   5,   5,   0,   2,  -1,   5,  -7,   0,   3,
#         -3], dtype=int32)]
# With MSE 18.87
# With MAE 3.4366666666666665
#
# Model cnn_v1_1e_5_40 behaved:
# [0.2, 83.50127439209358, array([ 16,   5,   7,   7,   7,   8,  -6,   0,   6,   3,   0,   2,   1,
#          3,   3,  -3,   9,   0,   5,   5,   2,  11,   8,  -2,   3,   0,
#          2,   5,   3,   3,   5,  -6,  -7,   2,   9,   7,  10,  10,   3,
#          5,  11,   3,  11,   3,   6,   7,  10,   4,   6,   8,   3,   6,
#          3,   0,   0,   0,   3,   6,   0,   0,   9,  -6,   1,   2,   6,
#          1,   1,   4,   0,   4,   3,   1,   2,  10,   4,   1,   6,   4,
#          5,   5,   6,   8,  -3,  -2,   0,   1,   2,   3,   7,   1,   4,
#          7,   6,  -6,   2,  -3,  -1,  -2,   1,   8,   6,   6,   2,   7,
#         12,   9,   4,   2,  10,   6,   6,   5,   7,   6,   7,  15,   9,
#         19,   5,   6,  -6,   4,   7,   9,   7,   5,   9,   5,  -2,  11,
#         12,   6,   5,  11,   9,   4,   7,   2,   2,   8,  11,   0,   9,
#         12,  16,   8,  14,  16,   2,   3,   6,   6,   5,   0,   6,   1,
#          4,   4,   8,   7,   4,   2,   2,   7,   3,  10,  10,   7,  -5,
#          7,   6,  -3,   4,   7,   7,   4,   5,   6,   6,   2,   1,  -1,
#          7,   7,   2,   3,   4,   8,   2,  -1,  -4,  -1,   4,  -3,   3,
#          5,   4,   6,   9,   7,   3,   3,   4,  13,   7,   4,   3,   6,
#          1,  -6,   1,   1, -10,  -6,  -2,  -1,   5,  11,   9,   9,   4,
#         -2,   4,   4,   8,  10,   5,   4,   2,  -3,  -1,   2,   4,   6,
#          1,   5,  -3,  -3,   3,   2,  -2,   8,  -1,   6,   6,   9,  -2,
#          6,   4,   4,  -5,   1,   0,  -3,  -1,   3,  -5,  -1,  -9,   5,
#         -5,   0,   5,  -2,   5,   6,  -2,   2,  -2,   5,   0,   2,  -1,
#        -13,   6,   6,   5,   9,   6,  11,   3,   3,  10,  -2,   7,  10,
#          8,  -3,   6,   4,   9,   7,   5,   6,  -1,   3,   0,   1,  11,
#          2], dtype=int32)]
# With MSE 36.64
# With MAE 5.0
#
# Model cnn_v1_1e_5_42 behaved:
# [0.30000000000000004, 88.727840098662, array([ -1,  -3,  -2,  -3,  -1,   7,  -9,   1,   5,   5,   4,   2,  -2,
#          3,  -1,  -3,   7,  -4,   3,   2,  -2,   8,   4,  -2,  -1,  -3,
#         -5,   0,  -1,   2,   1,  -6,  -7,   1,  -1,   3,   2,   6,  -1,
#          0,   4,  -3,   2,   1,   5,   0,   4,  -2,  -5,   3,  -1,   0,
#         -3,  -3,  -2,  -6,  -5,   1,  -3, -13,   2, -10,  -8,  -6,  -2,
#          2,  -2,  -7, -14,  -2,   3,  -2,   0,   7,   1,   0,  -4,  -2,
#          1,   0,   4,  -1,  -2,   0,  -2,  -5,  -2,  -2,   2,  -3,  -3,
#          2,  -3,  -9,  -5, -12,  -4, -10,  -1,   2,  -6,  -2,  -1,  -3,
#          4,   3,  -5,  -2,  -4,  -2,  -2,  -5,  -5,  -6,  -2,   3,   1,
#         10,   6,   0,  -7,  -2,   2,   3,  -2,   1,   2,  -4,  -7,   6,
#          3,  -2,  -5,  -1,   3,  -1,   5,   1,   1,   5,   9,  -4,   6,
#          2,   4,   0,   0,   5,  -2,  -1,   4,  -4,  -3,  -7,  -2,  -7,
#          0,  -2,   8,   4,   1,  -2,  -3,   0,   2,  -2,   2,   1,  -6,
#          0,  -3,  -5,   2,   4,   2,  -2,   1,   4,   1,   1,  -6,  -4,
#          4,  -1,  -5,  -1,  -1,   5,  -1,   0, -12,   0,   2,  -7,   0,
#         -2,  -1,   0,   1,   1,   1,   0,   4,   8,   5,  -1,  -1,   0,
#         -4,  -7,  -7,  -5, -11,  -9,  -4,  -6,  -1,   3,   5,   2,   1,
#         -5,   1,   4,  -1,   2,   3,   0,   3,  -1, -12,  -1,  -5,  -3,
#         -2,  -3,  -4,  -4,  -1,  -3, -12,  -2,  -7,  -8,   0,   3,  -6,
#          0,   0,   5,  -8,  -2,  -4,  -2,  -3,  -2,  -7,  -4,  -9,   3,
#         -8,  -2,  -3,  -9,  -2,   2, -10,  -5, -11,  -4,  -5,   0,  -2,
#        -16,   2,   3,   5,   1,   8,   5,  -4,   0,   3,  -6,  -1,   8,
#         10,  -2,   1,   2,   3,   6,  -1,  -1,   0,   4,  -8,  -3,   4,
#         -1], dtype=int32)]
# With MSE 20.516666666666666
# With MAE 3.49
#
# Model cnn_v1_1e_6_1 behaved:
# [0.30000000000000004, 86.21359653562126, array([ -2,  -8,  -4,  -6,  -5,   0,  -9,  -5,   4,   0,   0,   3,  -4,
#          1,  -2,  -4,  -2,  -8,  -1,  -1,  -3,   2,   2,  -4,   0,  -6,
#         -7,  -1,   0,   2,   1,  -9, -10,  -2,  -2,   0,   3,   1,  -5,
#         -5,   4,  -3,  -2,   0,   3,   2,   1,  -4,  -7,   4,  -2,  -4,
#         -2,  -5,  -2,  -6,  -9,  -4,  -8, -13,  -3, -13, -11,  -8,   2,
#         -2,  -6, -11, -16,   1,  -6,  -5,  -3,   1,  -3,  -1,  -1,  -8,
#          0,   2,   2,  -1,  -6,  -4,  -3,  -7,  -2,  -2,  -2,  -3,  -5,
#          3,  -3, -14, -11, -15,  -8,  -5,   1,   1,  -9,  -4,  -5,  -2,
#          4,   1,  -7,  -3,  -9,  -2,  -7,  -5,  -4,  -5,  -6,   0,  -2,
#          8,   0,   2,  -8,  -4,   4,   2,  -5,   0,   3,  -3,  -7,   2,
#          1,  -3,  -6,  -8,  -9,  -4,   0,  -2,  -4,  -1,   1,  -4,  -2,
#         -4,  -4,  -2, -10,   6,  -7,  -1,   2,  -3,  -5,  -9,  -7,  -9,
#         -2,  -6,   1,   3,   2,  -7,  -3,  -1,   0,  -6,  -5,  -5,  -7,
#         -2,  -4,  -7,   0,   0,   1,  -6,  -3,   1,   1,  -1,  -6,  -5,
#          1,  -2,  -4,  -3,  -4,  -3,  -4,   0,  -9,  -4,  -4,  -7,  -6,
#         -5,  -4,   0,  -2,  -1,  -3,  -2,  -3,   7,   2,  -2,  -4,  -1,
#         -7, -11,  -8,  -7, -13, -10,  -6,  -8,  -5,   1,  -1,  -3,  -4,
#         -6,  -5,  -2,  -4,   1,   0,  -1,  -5,  -7, -11,  -5,  -6,  -6,
#         -3,  -4,  -8,  -6,  -4,  -6, -12,  -3, -10, -12,  -7,   0,  -5,
#         -6,  -8,  -1,  -8,  -3,  -8,  -4,  -3,  -1,  -5,  -4, -10,  -1,
#        -10,  -5,  -2,  -7,  -4,  -5, -12,  -7, -10, -11, -10,  -6,  -5,
#        -20,  -1,  -1,   0,   1,   1,   5,  -8,   0,   0,  -9,  -5,   2,
#          4,  -4,  -3,  -5,  -2,   5,  -2,  -3,  -3,  -6, -11,  -4,  -2,
#         -6], dtype=int32)]
# With MSE 30.563333333333333
# With MAE 4.403333333333333
#
# Model cnn_v1_1e_6_21 behaved:
# [0.2, 86.50756702488911, array([  6,   5,   3,   2,   5,   6,  -5,   0,   8,   1,   0,   2,  -1,
#          3,   1,  -3,   8,   1,   6,   4,   1,  11,   3,  -3,   2,  -1,
#          1,   4,   2,   4,   3,  -5,  -6,   1,   5,   4,  10,   6,   2,
#          8,   6,   4,  11,   5,   6,   7,  10,   2,   2,   8,   2,   3,
#          0,  -2,  -1,  -5,   1,   6,  -6,  -6,   9,  -7,  -5,   2,   8,
#          3,  -3,   0,  -5,   5,   3,   2,   4,   7,   7,   1,   2,   3,
#          1,   4,   6,  10,  -4,   0,   0,  -2,   1,   1,   4,  -2,   2,
#          3,   4,  -6,  -1,  -7,   0,  -2,   2,   8,   6,   7,   5,   3,
#         11,   6,   0,  -1,   1,   4,   2,   6,   5,   2,   5,  11,  12,
#         16,   6,   6,  -2,   3,  11,   6,   2,   8,   5,   4,  -7,   9,
#          9,   4,   1,   3,   6,   2,   6,   1,  -1,   8,   9,  -2,   7,
#          8,  13,  10,   8,  16,   2,   5,   7,   5,   2,  -1,   2,  -2,
#          2,   5,   4,   5,   2,   2,   2,   3,   2,   5,   7,   2,  -5,
#          3,   1,  -4,   2,   3,   3,   1,   1,   7,   7,   1,  -1,  -1,
#          5,   2,  -1,   1,   1,   5,   2,   0,  -3,   1,   1,  -4,   1,
#         -1,   4,   8,   6,   6,   2,   3,   2,  11,   7,   2,  -1,   6,
#          0, -11,  -3,   0, -11,  -9,  -7,  -3,   5,   4,   9,   6,   3,
#          0,   1,   4,   7,   8,   4,   6,  -4,  -3,  -6,   1,   4,   2,
#          2,   2,  -4,  -2,   2,   1,  -5,   7,  -4,   6,   2,   9,   0,
#          5,   7,   6,  -4,   0,  -3,  -4,  -2,   3,  -5,   0,  -4,   2,
#         -2,  -3,   5,  -3,   1,   8,  -4,   4,  -5,  -2,  -4,   0,   0,
#        -15,   2,   2,   5,   2,   7,  12,   0,   2,  10,  -4,   5,   9,
#          8,  -1,   2,   2,   4,   5,   0,   0,   1,   5,  -3,   0,   7,
#          1], dtype=int32)]
# With MSE 26.63
# With MAE 4.123333333333333
#
# Model cnn_v1_1e_6_30 behaved:
# [0.30000000000000004, 83.45803010400732, array([  2,  -7,  -7,  -6,  -4,   0, -13,  -5,  -1,  -2,  -2,  -1,  -6,
#          1,  -4,  -5,  -2,  -7,  -3,  -3,  -5,   3,   0,  -7,  -5,  -6,
#         -6,  -2,   0,   2,   0, -10,  -9,  -4,  -1,  -3,   2,  -1,  -7,
#         -6,   4,  -4,  -1,  -2,   0,  -6,   1,  -1,  -4,   3,  -3,  -2,
#         -5,  -6,  -4,  -8,  -6,  -3,  -8, -20,  -4, -14, -14,  -7,  -2,
#         -3, -11, -11, -12,  -4,  -6,  -4,  -3,   2,  -4,  -2,  -6,  -6,
#         -2,  -3,   1,  -5,  -9,  -4,  -4,  -6,  -4,  -3,  -4,  -5,  -1,
#          2,  -4, -13, -14, -15,  -8, -10,  -4,  -4,  -3,  -2,  -4,  -3,
#          3,   3,  -6,  -6,  -9,  -5,  -4,  -4,  -8,  -8,  -5,   2,   1,
#          6,  -4,   2, -12,  -4,  -6,  -7,  -6,  -1,   0,  -3,  -9,   4,
#          2,  -4,  -4,  -3,  -6,  -3,  -1,  -1,  -6,   0,  -1,  -8,  -1,
#         -6,  -5,  -4,  -5,   5,  -9,  -2,  -2,  -4,  -4, -10,  -7, -11,
#         -3,  -8,   0,   3,  -8,  -9, -11,  -3,  -2,  -7,  -3,  -8,  -7,
#          0,  -1,  -7,  -1,  -2,  -2,  -3,  -4,   0,   1,   0,  -7,  -7,
#         -2,  -6,  -6,  -8,  -5,  -2,  -5,  -1, -10,  -3,  -8,  -6,  -7,
#         -6,  -5,   0,  -2,  -3,  -5,  -2,  -7,   2,   0,  -3,  -3,  -6,
#         -7, -12,  -9,  -9, -11, -12, -12,  -6,  -2,  -2,  -2,  -6,  -3,
#         -7,  -7,  -5,  -7,  -3,   1,  -3, -10, -12, -10,  -6,  -5,  -9,
#         -2,  -7,  -8,  -8,  -2,  -6, -11,   2, -13, -12,  -5,  -5, -10,
#         -9,  -9,  -2,  -7,  -6,  -8,  -6,  -6,  -3, -12,  -8, -11,  -1,
#        -11, -10,  -4, -12,  -6,  -9, -13,  -9, -12, -12, -11, -10, -11,
#        -22,  -6,  -4,   1,  -5,  -3,   3,  -6,  -3,  -2,  -8,  -6,   2,
#          1,  -8,  -5,  -5,  -2,  -2,  -5,  -1,  -5,  -5, -10,  -5,   0,
#         -5], dtype=int32)]
# With MSE 41.10666666666667
# With MAE 5.273333333333333
